# %% [markdown]
# # **Task 1:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  # Corrected the import for matplotlib
import seaborn as sns  # Corrected the import for seaborn

# %% [markdown]
# # **My Dataset links**

# %% [markdown]
# Content1= https://drive.google.com/file/d/1f3YVHXzqkMW9J2fKFRGWik2OrZv9rPPM/view?usp=sharing
#
# Reactions1= https://drive.google.com/file/d/1z2G-CET0EHqY_Eco_ArG_9moHhSrdgba/view?usp=sharing
#
# ReactionTypes1= https://drive.google.com/file/d/1Xg05SBLHmUJD8TfTPCzp7Trs5FMJwm7n/view?usp=sharing

# %%
# Load the data files
reactions = pd.read_csv('/content/Content1.csv')
content = pd.read_csv('/content/Reactions1.csv')
reaction_types = pd.read_csv('/content/ReactionTypes1.csv')

# %%
# Display the first few rows of each dataset
print("Reactions Dataset:")
display(reactions.head(), "\n")

print("Content Dataset:")
display(content.head(), "\n")

print("Reaction Types Dataset:")
display(reaction_types.head(), "\n")
# Out:
# Reactions Dataset:
#    Unnamed: 0                            Content ID Content Type  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180        video
#
#          Category
# 0        Studying
# 1  healthy eating
# 2  healthy eating
# 3      technology
# 4            food
# '\n'
# Content Dataset:
#    Column1                            Content ID Reaction Type  \
# 0        1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1        2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2        3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3        4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4        5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
#
#            Datetime
# ...

# %%
# Check for basic info and missing values
print("Reactions Info:")
print(reactions.info(), "\n")

print("Content Info:")
print(content.info(), "\n")

print("Reaction Types Info:")
print(reaction_types.info(), "\n")
# Out:
# Reactions Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1000 non-null   int64
#  1   Content ID    1000 non-null   object
#  2   Content Type  1000 non-null   object
#  3   Category      1000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 31.4+ KB
# None
#
# Content Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24573 entries, 0 to 24572
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Column1        24573 non-null  int64
#  1   Content ID     24573 non-null  object
#  2   Reaction Type  24573 non-null  object
#  3   Datetime       24573 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 768.0+ KB
# None
#
# Reaction Types Info:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# Check for missing values and handle them

display(content.isnull().sum(), "\n")
display(reactions.isnull().sum(), "\n")
display(reaction_types.isnull().sum(), "\n")
# Out:
# Column1          0
# Content ID       0
# Reaction Type    0
# Datetime         0
# dtype: int64
# '\n'
# Unnamed: 0      0
# Content ID      0
# Content Type    0
# Category        0
# dtype: int64
# '\n'
# Column1      0
# Type         0
# Sentiment    0
# Score        0
# dtype: int64
# '\n'

# %% [markdown]
# **Note:there is no Missing Values**

# %% [markdown]
# # **Task 2:**

# %% [markdown]
# **link:**
#
#  https://docs.google.com/spreadsheets/d/12mfwmXW4ReZKGAxLKGj6sf4oIkQ4HzW0/edit?usp=sharing&ouid=109096783554977851195&rtpof=true&sd=true

# %% [markdown]
# ## **Task 3:**

# %% [markdown]
# **Link:**
#
# https://docs.google.com/spreadsheets/d/1GX_NgJzDJwgTyJeufyyFGdt3LaEhqGzZ/edit?usp=sharing&ouid=109096783554977851195&rtpof=true&sd=true

# %% [markdown]
# # **Task 4:**

# %% [markdown]
# **Link:**   https://drive.google.com/file/d/10cUFMen1DoCqVXPfo0NGFW_RJJ4GOIPy/view?usp=sharing

# %% [markdown]
# # **Categories:**
#
# Studying, Healthy Eating, Technology, Food, Cooking, Dogs, Soccer, Public Speaking, Science, Tennis, Travel, Fitness, Education, Veganism, Animals, Culture
#
# # **Content Types:**
#
# Photo,Video,GIF,Audio
#
# # **Sentiments:**
# Negative,Positive,Neutral ​

# %% [markdown]
# # **Summary:**

# %% [markdown]
# **This project analyzed Social Buzz’s data to find the top 5 most popular content categories and help improve the platform. The team cleaned and studied large amounts of unstructured data (like posts) to uncover useful insights.**

# %% [markdown]
# # **Key Highlights:**
#
# **Understanding the Problem:**
#
# Social Buzz handles over 100,000 posts daily (36.5 million annually), mostly unstructured data.
#
# The challenge was to extract meaningful insights to enhance the platform's user experience.
#
# **Approach:**
#
# Data Understanding: Analyzed the data structure and business domain
# .
# Data Cleaning: Processed the raw data to create a usable dataset.
#
# Data Modeling: Structured the data to answer specific business questions.
#
# Data Analysis: Conducted analysis and visualized insights.
#
# Recommendations: Formulated strategies based on findings.
#
# **Findings**:
#
# **The top 5 content categories were Animals, Science, Healthy Eating, Technology, and Food.**
#
# The "Animals" category stood out as the most popular, highlighting users’ love for relatable and factual content.
#
# "Healthy Eating" outperformed "Food," suggesting a health-conscious audience.
#
# **Business Recommendations:**
#
# Use these insights to run targeted campaigns (e.g., collaborations with health brands).
#
# Maintain content balance to ensure diversity and engagement.
